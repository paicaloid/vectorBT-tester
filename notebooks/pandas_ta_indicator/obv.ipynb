# %%
import pandas_ta as ta
from utils.plot_helper import plot_1_line, plot_2_line
import numpy as np

# %%
# Silence warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = catalog.load("GOOG_OBV")
df
# Out:
# [04/04/23 16:12:43] INFO     Loading data from 'GOOG_OBV' (ParquetDataSet)...                   ]8;id=637221;file:///opt/anaconda3/envs/vectorbt/lib/python3.8/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=402354;file:///opt/anaconda3/envs/vectorbt/lib/python3.8/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                           open        high         low     close    Volume
# time
# 2019-12-13T14:30:00Z   67.3975   67.654655   67.193500   67.3915  31000560  \
# 2019-12-16T14:30:00Z   67.8250   68.234000   67.633500   68.0585  27949020
# 2019-12-17T14:30:00Z   68.1445   68.250000   67.566155   67.7560  37105180
# 2019-12-18T14:30:00Z   67.8300   68.023500   67.550000   67.6310  33141380
# 2019-12-19T14:30:00Z   67.5910   67.905000   67.449250   67.8020  29402240
# ...                        ...         ...         ...       ...       ...
# 2023-03-27T13:30:00Z  105.3200  105.400000  102.630000  103.0600  25393417
# ...

# %%
df_pandas = df[['open', 'high', 'low', 'close','Volume']]
df_pandas.ta.obv(append=True)
df_pandas
# Out:
#                           open        high         low     close    Volume
# time
# 2019-12-13T14:30:00Z   67.3975   67.654655   67.193500   67.3915  31000560  \
# 2019-12-16T14:30:00Z   67.8250   68.234000   67.633500   68.0585  27949020
# 2019-12-17T14:30:00Z   68.1445   68.250000   67.566155   67.7560  37105180
# 2019-12-18T14:30:00Z   67.8300   68.023500   67.550000   67.6310  33141380
# 2019-12-19T14:30:00Z   67.5910   67.905000   67.449250   67.8020  29402240
# ...                        ...         ...         ...       ...       ...
# 2023-03-27T13:30:00Z  105.3200  105.400000  102.630000  103.0600  25393417
# 2023-03-28T13:30:00Z  103.0000  103.000000  100.280000  101.3600  24913480
# 2023-03-29T13:30:00Z  102.7200  102.820000  101.030000  101.9000  26148300
# 2023-03-30T13:30:00Z  101.4400  101.610000  100.290000  101.3200  25009829
# 2023-03-31T13:30:00Z  101.7100  104.190000  101.440000  104.0000  28107953
#
#                                OBV
# time
# ...

# %%
plot_2_line(df.index,df['OnBalanceVolume'],df_pandas['OBV'],'OBV','OBV_pandas','OBV')
plot_1_line(df.index,np.absolute(df['OnBalanceVolume']-df_pandas['OBV']),'OBV_diff')
