# %%
import pandas_ta as ta
from utils.plot_helper import plot_1_line, plot_2_line
import numpy as np

# %%
# Silence warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = catalog.load("GOOG_EMA_5")
df
# Out:
# [04/04/23 16:04:19] INFO     Loading data from 'GOOG_EMA_5' (ParquetDataSet)...                 ]8;id=773785;file:///opt/anaconda3/envs/vectorbt/lib/python3.8/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=328683;file:///opt/anaconda3/envs/vectorbt/lib/python3.8/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                          open       high       low     close         EMA
# time
# 2017-09-27T13:30:00Z   46.387   47.49500   46.3870   47.2245   46.588449  \
# 2017-09-28T13:30:00Z   47.068   47.53450   47.0275   47.4750   46.883966
# 2017-09-29T13:30:00Z   47.600   47.98932   47.5755   47.9555   47.241144
# 2017-10-02T13:30:00Z   47.999   48.12700   47.3920   47.6635   47.381929
# 2017-10-03T13:30:00Z   47.700   47.90000   47.4570   47.8895   47.551119
# ...                       ...        ...       ...       ...         ...
# 2023-03-27T13:30:00Z  105.320  105.40000  102.6300  103.0600  104.045447
# ...

# %%
df_pandas = df[['open', 'high', 'low', 'close']]
df_pandas.ta.ema(length = 5,append=True)
df_pandas
# Out:
#                          open       high       low     close       EMA_5
# time
# 2017-09-27T13:30:00Z   46.387   47.49500   46.3870   47.2245         NaN
# 2017-09-28T13:30:00Z   47.068   47.53450   47.0275   47.4750         NaN
# 2017-09-29T13:30:00Z   47.600   47.98932   47.5755   47.9555         NaN
# 2017-10-02T13:30:00Z   47.999   48.12700   47.3920   47.6635         NaN
# 2017-10-03T13:30:00Z   47.700   47.90000   47.4570   47.8895   47.641600
# ...                       ...        ...       ...       ...         ...
# 2023-03-27T13:30:00Z  105.320  105.40000  102.6300  103.0600  104.045447
# 2023-03-28T13:30:00Z  103.000  103.00000  100.2800  101.3600  103.150298
# 2023-03-29T13:30:00Z  102.720  102.82000  101.0300  101.9000  102.733532
# 2023-03-30T13:30:00Z  101.440  101.61000  100.2900  101.3200  102.262355
# 2023-03-31T13:30:00Z  101.710  104.19000  101.4400  104.0000  102.841570
#
# [1387 rows x 5 columns]

# %%
plot_2_line(df.index,df['EMA'],df_pandas['EMA_5'],'EMA_5','EMA_5_pandas','EMA_5')
plot_1_line(df.index,np.absolute(df['EMA']-df_pandas['EMA_5']),'EMA_5_diff')
