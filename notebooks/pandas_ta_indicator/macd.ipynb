# %%
import pandas_ta as ta
from utils.plot_helper import plot_1_line, plot_2_line
import numpy as np

# %%
# Silence warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = catalog.load("GOOG_MACD")
df
# Out:
# [04/04/23 16:09:45] INFO     Loading data from 'GOOG_MACD' (ParquetDataSet)...                  ]8;id=644579;file:///opt/anaconda3/envs/vectorbt/lib/python3.8/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=778807;file:///opt/anaconda3/envs/vectorbt/lib/python3.8/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                          open       high       low     close  Histogram
# time
# 2017-09-27T13:30:00Z   46.387   47.49500   46.3870   47.2245   0.056530  \
# 2017-09-28T13:30:00Z   47.068   47.53450   47.0275   47.4750   0.108351
# 2017-09-29T13:30:00Z   47.600   47.98932   47.5755   47.9555   0.165693
# 2017-10-02T13:30:00Z   47.999   48.12700   47.3920   47.6635   0.173812
# 2017-10-03T13:30:00Z   47.700   47.90000   47.4570   47.8895   0.183315
# ...                       ...        ...       ...       ...        ...
# 2023-03-27T13:30:00Z  105.320  105.40000  102.6300  103.0600   1.091188
# ...

# %%
df_pandas = df[['open', 'high', 'low', 'close']]
df_pandas.ta.macd(append=True)
df_pandas
# Out:
#                          open       high       low     close  MACD_12_26_9
# time
# 2017-09-27T13:30:00Z   46.387   47.49500   46.3870   47.2245           NaN  \
# 2017-09-28T13:30:00Z   47.068   47.53450   47.0275   47.4750           NaN
# 2017-09-29T13:30:00Z   47.600   47.98932   47.5755   47.9555           NaN
# 2017-10-02T13:30:00Z   47.999   48.12700   47.3920   47.6635           NaN
# 2017-10-03T13:30:00Z   47.700   47.90000   47.4570   47.8895           NaN
# ...                       ...        ...       ...       ...           ...
# 2023-03-27T13:30:00Z  105.320  105.40000  102.6300  103.0600      2.776530
# 2023-03-28T13:30:00Z  103.000  103.00000  100.2800  101.3600      2.564386
# 2023-03-29T13:30:00Z  102.720  102.82000  101.0300  101.9000      2.412029
# 2023-03-30T13:30:00Z  101.440  101.61000  100.2900  101.3200      2.218906
# 2023-03-31T13:30:00Z  101.710  104.19000  101.4400  104.0000      2.256101
#
#                       MACDh_12_26_9  MACDs_12_26_9
# time
# ...

# %%
plot_2_line(df.index,df['MACD'],df_pandas['MACD_12_26_9'],'MACD','MACD_pandas','MACD')
plot_1_line(df.index,np.absolute(df['MACD']-df_pandas['MACD_12_26_9']),'MACD_diff')

plot_2_line(df.index,df['Histogram'],df_pandas['MACDh_12_26_9'],'MACD_histogram','MACD_histogram_pandas','MACD Histogram')
plot_1_line(df.index,np.absolute(df['Histogram']-df_pandas['MACDh_12_26_9']),'Histogram diff')

plot_2_line(df.index,df['Signal'],df_pandas['MACDs_12_26_9'],'MACD_signal','MACD_signal_pandas','MACD Signal')
plot_1_line(df.index,np.absolute(df['MACD']-df_pandas['MACD_12_26_9']),'Signal diff')
