# %%
import pandas_ta as ta
from utils.plot_helper import plot_1_line, plot_2_line
import numpy as np

# %%
# Silence warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = catalog.load("GOOG_STOCH")
df
# Out:
# [04/04/23 16:59:24] INFO     Loading data from 'GOOG_STOCH' (ParquetDataSet)...                 ]8;id=915971;file:///opt/anaconda3/envs/vectorbt/lib/python3.8/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=158231;file:///opt/anaconda3/envs/vectorbt/lib/python3.8/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                          open       high       low     close           K
# time
# 2017-09-27T13:30:00Z   46.387   47.49500   46.3870   47.2245   60.407885  \
# 2017-09-28T13:30:00Z   47.068   47.53450   47.0275   47.4750   83.687556
# 2017-09-29T13:30:00Z   47.600   47.98932   47.5755   47.9555  100.000000
# 2017-10-02T13:30:00Z   47.999   48.12700   47.3920   47.6635   94.173557
# 2017-10-03T13:30:00Z   47.700   47.90000   47.4570   47.8895   91.085091
# ...                       ...        ...       ...       ...         ...
# 2023-03-27T13:30:00Z  105.320  105.40000  102.6300  103.0600   82.988891
# ...

# %%
df_pandas = df[['open', 'high', 'low', 'close',]]
df_pandas.ta.stochrsi(append=True)
df_pandas
# Out:
#                          open       high       low     close
# time
# 2017-09-27T13:30:00Z   46.387   47.49500   46.3870   47.2245  \
# 2017-09-28T13:30:00Z   47.068   47.53450   47.0275   47.4750
# 2017-09-29T13:30:00Z   47.600   47.98932   47.5755   47.9555
# 2017-10-02T13:30:00Z   47.999   48.12700   47.3920   47.6635
# 2017-10-03T13:30:00Z   47.700   47.90000   47.4570   47.8895
# ...                       ...        ...       ...       ...
# 2023-03-27T13:30:00Z  105.320  105.40000  102.6300  103.0600
# 2023-03-28T13:30:00Z  103.000  103.00000  100.2800  101.3600
# 2023-03-29T13:30:00Z  102.720  102.82000  101.0300  101.9000
# 2023-03-30T13:30:00Z  101.440  101.61000  100.2900  101.3200
# 2023-03-31T13:30:00Z  101.710  104.19000  101.4400  104.0000
#
#                       STOCHRSIk_14_14_3_3  STOCHRSId_14_14_3_3
# time
# 2017-09-27T13:30:00Z                  NaN                  NaN
# 2017-09-28T13:30:00Z                  NaN                  NaN
# ...

# %%
plot_2_line(df.index,df['K'],df_pandas['STOCHRSIk_14_14_3_3'],'STOCH_RSI_K','STOCH_RSI_K_pandas','STOCH_RSI_K')
plot_1_line(df.index,np.abs(df['K']-df_pandas['STOCHRSIk_14_14_3_3']),'diff STOCH_RSI_K')
plot_2_line(df.index,df['D'],df_pandas['STOCHRSId_14_14_3_3'],'STOCH_RSI_D','STOCH_RSI_D_pandas','STOCH_RSI_D')
plot_1_line(df.index,np.abs(df['D']-df_pandas['STOCHRSId_14_14_3_3']),'diff STOCH_RSI_D')
