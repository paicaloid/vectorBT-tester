# %%
catalog.load("GOOG_MERGE_DATA").head()
# Out:
# [04/05/23 11:06:57] INFO     Loading data from 'GOOG_MERGE_DATA' (ParquetDataSet)...            ]8;id=148664;file:///Users/apinya/opt/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=371030;file:///Users/apinya/opt/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                       open_GOOG_1D_ADX  high_GOOG_1D_ADX  low_GOOG_1D_ADX  \
# time
# 2017-09-27T13:30:00Z            46.387          47.49500          46.3870
# 2017-09-28T13:30:00Z            47.068          47.53450          47.0275
# 2017-09-29T13:30:00Z            47.600          47.98932          47.5755
# 2017-10-02T13:30:00Z            47.999          48.12700          47.3920
# 2017-10-03T13:30:00Z            47.700          47.90000          47.4570
#
#                       close_GOOG_1D_ADX  open_GOOG_1D_BB_20_STD_2  \
# time
# 2017-09-27T13:30:00Z            47.2245                    46.387
# ...

# %%
from kedro.framework.context import KedroContext
